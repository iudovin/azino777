# %%
import os
os.listdir('dags/csv')
# Out:
# ['currency_rates',
#  'currency_rates.csv',
#  'deposits',
#  'deposits.csv',
#  'games',
#  'games.csv',
#  'games_map.csv',
#  'players',
#  'players.csv',
#  'providers_map.csv',
#  'withdrawals',
#  'withdrawals.csv']

# %%
import pandas as pd
df = pd.read_csv('dags/csv/withdrawals.csv')
df.count(),df.head()
# Out:
# (id                 3000
#  player_id          3000
#  withdrawal_date    3000
#  provider_id        3000
#  amount             3000
#  currency           3000
#  dtype: int64,
#     id  player_id withdrawal_date  provider_id  amount currency
#  0   1          3      2024-02-20            1  885.51      USD
#  1   2        903      2023-08-12            1   59.76      USD
#  2   3        525      2023-08-31            3  222.66      USD
#  3   4        462      2024-02-25            1  452.18      RUB
#  4   5        754      2023-06-12            1  189.44      RUB)

# %%
df[df.withdrawal_date>='2024-01-01'].sum()
# Out:
# id                                                            663095
# player_id                                                     224765
# withdrawal_date    2024-02-202024-02-252024-01-202024-02-232024-0...
# provider_id                                                     2480
# amount                                                     228898.44
# currency           USDRUBGBPGBPGBPRUBEURGBPUSDRUBEURUSDGBPGBPEURG...
# dtype: object

# %% [markdown]
# - **currency_rates**: 1704 rows, days from 2023-01-01 to 2024-03-01
# - **deposits**: 5000 rows, id 1-5000
# - **games**: 7000 rows, id 1-7000
# - **games_map**: 50 rows
# - **providers_map**: 10 rows
# - **players**: 1000 rows, id 1-1000
# - **withdrawals**: 3000 rows, id 1-3000
